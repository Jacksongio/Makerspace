# %%
from langchain_ollama import OllamaEmbeddings

embeddings = OllamaEmbeddings(
    model="mxbai-embed-large",
)

# %%
from langchain_community.document_loaders import JSONLoader
from langchain_community.document_loaders import DirectoryLoader

json_loader = DirectoryLoader(
    path="./data/data",
    glob="**/*.json",
    loader_cls=JSONLoader,
    loader_kwargs={"jq_schema" : "..", "text_content" : False}
)
json_documents = json_loader.load()

# %%
len(json_documents)
# Out:
# 5828

# %% [markdown]
# > NOTE: This cell will take a while (~15min) as there are a lot of documents - please ensure you'd selected your own data before running this cell.

# %%
from langchain_qdrant import QdrantVectorStore

url = "127.0.0.1:6334"
qdrant = QdrantVectorStore.from_documents(
    json_documents,
    embeddings,
    url=url,
    prefer_grpc=True,
    collection_name="DnD_Documents",
)
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 from langchain_qdrant import QdrantVectorStore
#       3 url = "127.0.0.1:6334"
# ----> 4 qdrant = QdrantVectorStore.from_documents(
#       5     json_documents,
#       6     embeddings,
#       7     url=url,
#       8     prefer_grpc=True,
#       9     collection_name="DnD_Documents",
#      10 )
#
# File ~/dev/Makerspace/18_On_Prem_Agent/.venv/lib/python3.13/site-packages/langchain_core/vectorstores/base.py:848, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     845     if any(ids):
#     846         kwargs["ids"] = ids
# --> 848 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File ~/dev/Makerspace/18_On_Prem_Agent/.venv/lib/python3.13/site-packages/langchain_qdrant/qdrant.py:343, in QdrantVectorStore.from_texts(cls, texts, embedding, metadatas, ids, collection_name, location, url, port, grpc_port, prefer_grpc, https, api_key, prefix, timeout, host, path, distance, content_payload_key, metadata_payload_key, vector_name, retrieval_mode, sparse_embedding, sparse_vector_name, collection_create_options, vector_params, sparse_vector_params, batch_size, force_recreate, validate_embeddings, validate_collection_config, **kwargs)
#     311 """Construct an instance of `QdrantVectorStore` from a list of texts.
#     312
#     313 This is a user-friendly interface that:
#    (...)    326     qdrant = Qdrant.from_texts(texts, embeddings, url="http://localhost:6333")
#     327 """
#     328 client_options = {
#     329     "location": location,
#     330     "url": url,
#    (...)    340     **kwargs,
#     341 }
# --> 343 qdrant = cls.construct_instance(
#     344     embedding,
#     345     retrieval_mode,
#     346     sparse_embedding,
#     347     client_options,
#     348     collection_name,
#     349     distance,
#     350     content_payload_key,
#     351     metadata_payload_key,
#     352     vector_name,
#     353     sparse_vector_name,
#     354     force_recreate,
#     355     collection_create_options,
#     356     vector_params,
#     357     sparse_vector_params,
#     358     validate_embeddings,
#     359     validate_collection_config,
#     360 )
#     361 qdrant.add_texts(texts, metadatas, ids, batch_size)
#     362 return qdrant
#
# File ~/dev/Makerspace/18_On_Prem_Agent/.venv/lib/python3.13/site-packages/langchain_qdrant/qdrant.py:810, in QdrantVectorStore.construct_instance(cls, embedding, retrieval_mode, sparse_embedding, client_options, collection_name, distance, content_payload_key, metadata_payload_key, vector_name, sparse_vector_name, force_recreate, collection_create_options, vector_params, sparse_vector_params, validate_embeddings, validate_collection_config)
#     807 collection_name = collection_name or uuid.uuid4().hex
#     808 client = QdrantClient(**client_options)
# --> 810 collection_exists = client.collection_exists(collection_name)
#     812 if collection_exists and force_recreate:
#     813     client.delete_collection(collection_name)
#
# File ~/dev/Makerspace/18_On_Prem_Agent/.venv/lib/python3.13/site-packages/qdrant_client/qdrant_client.py:2236, in QdrantClient.collection_exists(self, collection_name, **kwargs)
#    2226 """Check whether collection already exists
#    2227
#    2228 Args:
#    (...)   2232     True if collection exists, False if not
#    2233 """
#    2234 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
# -> 2236 return self._client.collection_exists(collection_name=collection_name, **kwargs)
#
# File ~/dev/Makerspace/18_On_Prem_Agent/.venv/lib/python3.13/site-packages/qdrant_client/qdrant_remote.py:2592, in QdrantRemote.collection_exists(self, collection_name, **kwargs)
#    2590 def collection_exists(self, collection_name: str, **kwargs: Any) -> bool:
#    2591     if self._prefer_grpc:
# -> 2592         return self.grpc_collections.CollectionExists(
#    2593             grpc.CollectionExistsRequest(collection_name=collection_name),
#    2594             timeout=self._timeout,
#    2595         ).result.exists
#    2597     result: Optional[models.CollectionExistence] = self.http.collections_api.collection_exists(
#    2598         collection_name=collection_name
#    2599     ).result
#    2600     assert result is not None, "Collection exists returned None"
#
# File ~/dev/Makerspace/18_On_Prem_Agent/.venv/lib/python3.13/site-packages/grpc/_interceptor.py:277, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     268 def __call__(
#     269     self,
#     270     request: Any,
#    (...)    275     compression: Optional[grpc.Compression] = None,
#     276 ) -> Any:
# --> 277     response, ignored_call = self._with_call(
#     278         request,
#     279         timeout=timeout,
#     280         metadata=metadata,
#     281         credentials=credentials,
#     282         wait_for_ready=wait_for_ready,
#     283         compression=compression,
#     284     )
#     285     return response
#
# File ~/dev/Makerspace/18_On_Prem_Agent/.venv/lib/python3.13/site-packages/grpc/_interceptor.py:332, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     327         return _FailureOutcome(exception, sys.exc_info()[2])
#     329 call = self._interceptor.intercept_unary_unary(
#     330     continuation, client_call_details, request
#     331 )
# --> 332 return call.result(), call
#
# File ~/dev/Makerspace/18_On_Prem_Agent/.venv/lib/python3.13/site-packages/grpc/_channel.py:440, in _InactiveRpcError.result(self, timeout)
#     436 def result(
#     437     self, timeout: Optional[float] = None
#     438 ) -> Any:  # pylint: disable=unused-argument
#     439     """See grpc.Future.result."""
# --> 440     raise self
#
# File ~/dev/Makerspace/18_On_Prem_Agent/.venv/lib/python3.13/site-packages/grpc/_interceptor.py:315, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     306 (
#     307     new_method,
#     308     new_timeout,
#    (...)    312     new_compression,
#     313 ) = _unwrap_client_call_details(new_details, client_call_details)
#     314 try:
# --> 315     response, call = self._thunk(new_method).with_call(
#     316         request,
#     317         timeout=new_timeout,
#     318         metadata=new_metadata,
#     319         credentials=new_credentials,
#     320         wait_for_ready=new_wait_for_ready,
#     321         compression=new_compression,
#     322     )
#     323     return _UnaryOutcome(response, call)
#     324 except grpc.RpcError as rpc_error:
#
# File ~/dev/Makerspace/18_On_Prem_Agent/.venv/lib/python3.13/site-packages/grpc/_channel.py:1192, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1180 def with_call(
#    1181     self,
#    1182     request: Any,
#    (...)   1187     compression: Optional[grpc.Compression] = None,
#    1188 ) -> Tuple[Any, grpc.Call]:
#    1189     state, call = self._blocking(
#    1190         request, timeout, metadata, credentials, wait_for_ready, compression
#    1191     )
# -> 1192     return _end_unary_response_blocking(state, call, True, None)
#
# File ~/dev/Makerspace/18_On_Prem_Agent/.venv/lib/python3.13/site-packages/grpc/_channel.py:1006, in _end_unary_response_blocking(state, call, with_call, deadline)
#    1004         return state.response
#    1005 else:
# -> 1006     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses; last error: UNKNOWN: ipv4:127.0.0.1:6334: Failed to connect to remote host: connect: Connection refused (111)"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:127.0.0.1:6334: Failed to connect to remote host: connect: Connection refused (111)"}"
# >
